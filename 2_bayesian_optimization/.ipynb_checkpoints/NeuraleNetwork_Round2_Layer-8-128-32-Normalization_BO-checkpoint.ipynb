# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import *
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD,Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import LambdaCallback

# %%
weight_log1=[]
weight_log2=[]
weight_log3=[]
print_weights1 = LambdaCallback(on_epoch_end=lambda epoch,_: weight_log1.append(NN.layers[0].get_weights()[0].tolist()) if epoch%500==0 else False)
print_weights2 = LambdaCallback(on_epoch_end=lambda epoch,_: weight_log2.append(NN.layers[1].get_weights()[0].tolist()) if epoch%500==0 else False)
print_weights3 = LambdaCallback(on_epoch_end=lambda epoch,_: weight_log3.append(NN.layers[2].get_weights()[0].tolist()) if epoch%500==0 else False)

# %%
SurfaceData=pd.read_csv('SurfaceData_SUM_4200_21.csv',delimiter=";")

# %%
for i in range(len(SurfaceData)):
    SurfaceData["bins"][i]=np.fromstring(SurfaceData["bins"][i][1:-2],sep=',')
    SurfaceData["n0"][i]=np.fromstring(SurfaceData["n0"][i][1:-2],sep=',')
    SurfaceData["Qquerys"][i]=np.fromstring(SurfaceData["Qquerys"][i][1:-2],sep=',')
    SurfaceData["PSquerys"][i]=np.fromstring(SurfaceData["PSquerys"][i][1:-2],sep=',')
# Out:
# <ipython-input-8-01e08cc89346>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SurfaceData["bins"][i]=np.fromstring(SurfaceData["bins"][i][1:-2],sep=',')
# <ipython-input-8-01e08cc89346>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SurfaceData["n0"][i]=np.fromstring(SurfaceData["n0"][i][1:-2],sep=',')
# <ipython-input-8-01e08cc89346>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SurfaceData["Qquerys"][i]=np.fromstring(SurfaceData["Qquerys"][i][1:-2],sep=',')
# <ipython-input-8-01e08cc89346>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SurfaceData["PSquerys"][i]=np.fromstring(SurfaceData["PSquerys"][i][1:-2],sep=',')

# %%
SurfaceData
# Out:
#       Surface_ID        kt    lambda0   lambda1  \
# 0              0  0.133822   5.543702  0.358684
# 1              1  0.128934  11.643065  0.372285
# 2              2  0.143972  12.394254  0.333398
# 3              3  0.153670  10.619974  0.312358
# 4              4  0.205617  10.788297  0.233444
# ...          ...       ...        ...       ...
# 4216        4216  0.109481   8.768670  0.438434
# 4217        4217  0.142063   6.757554  0.337878
# 4218        4218  0.159412   6.022141  0.301107
# 4219        4219  0.136698   7.022781  0.351139
# 4220        4220  0.098137  12.195122  0.365854
#
#                                                    bins  \
# 0     [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 1     [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 2     [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 3     [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 4     [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# ...                                                 ...
# 4216  [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 4217  [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 4218  [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 4219  [0.0, 0.034, 0.068, 0.10200000000000001, 0.136...
# 4220  [0.0, 0.03333333333333333, 0.06666666666666667...
#
#                                                      n0  \
# 0     [0.06906762705082033, 0.022889155662264904, 0....
# 1     [0.06559925745446107, 0.027752639517345398, 0....
# 2     [0.052305010893246184, 0.055250544662309366, 0...
# 3     [0.0569827931172469, 0.07819127651060423, 0.15...
# 4     [0.05533648362392048, 0.04915539623051437, 0.0...
# ...                                                 ...
# 4216  [0.04662990196078431, 0.052512254901960785, 0....
# 4217  [0.07457107843137255, 0.033884803921568625, 0....
# 4218  [0.11709558823529412, 1.628063725490196, 6.223...
# 4219  [0.07708333333333334, 0.03756127450980392, 0.0...
# 4220  [19.6546875, 0.69140625, 0.7692187499999998, 0...
#
#                                                 Qquerys  \
# 0     [1.0, 1.099013455112193, 1.2078305745176405, 1...
# 1     [1.0, 1.1260517245293826, 1.2679924863155967, ...
# 2     [1.0, 1.1327832043001638, 1.2831977879445464, ...
# 3     [1.0, 1.129300035455426, 1.2753185700796263, 1...
# 4     [1.0, 1.1413159270960496, 1.3026020454431149, ...
# ...                                                 ...
# 4216  [1.0, 1.1088252403758785, 1.229493413694625, 1...
# 4217  [1.0, 1.1088252403758785, 1.229493413694625, 1...
# 4218  [1.0, 1.1088252403758785, 1.229493413694625, 1...
# 4219  [1.0, 1.1088252403758785, 1.229493413694625, 1...
# 4220  [1.0, 1.128529874371643, 1.2735796773492765, 1...
#
#                                                PSquerys      K_99       DU  \
# 0     [2.050417958769348, 2.0436401816920546, 2.0177...  0.116473      NaN
# 1     [1.8501848010002164, 1.8466317028999026, 1.845...  0.112131      NaN
# 2     [2.0851597049304424, 2.085722022118843, 2.0873...  0.119977      NaN
# 3     [2.2286230268404137, 2.2295565709294176, 2.226...  0.128058      NaN
# 4     [2.5835627610683582, 2.5490008761146528, 2.480...  0.171347      NaN
# ...                                                 ...       ...      ...
# 4216  [2.022047326714934, 2.017577209921213, 2.00308...  0.118386   5.9600
# 4217  [2.005488935018274, 2.0039038886079905, 1.9935...  0.132843   6.3772
# 4218  [1.7167578251648266, 1.7186645483758225, 1.718...  0.113915   9.5994
# 4219  [1.7350076805197128, 1.7348967797387072, 1.735...  0.089256   7.5100
# 4220  [1.728012991798361, 1.728932145170728, 1.72932...  0.082000  10.0000
#
#             ks        kr
# 0     0.004797  0.041184
# 1     0.004797  0.042778
# 2     0.004797  0.039981
# 3     0.004797  0.037458
# 4     0.004797  0.027994
# ...        ...       ...
# 4216  0.088371  0.968623
# 4217  0.104857  0.885723
# 4218  0.392957  2.958056
# 4219  0.166842  1.464619
# 4220  0.103000  1.256098
#
# [4221 rows x 12 columns]

# %%
SurfaceData_Simulated=SurfaceData[SurfaceData["DU"].notna()]
SurfaceData_Simulated=SurfaceData_Simulated[SurfaceData["DU"]>=6]
SurfaceData_Pool=SurfaceData[SurfaceData["DU"].isna()]
ListOfLabledID=SurfaceData_Simulated["Surface_ID"].to_numpy()
DUTrain=SurfaceData_Simulated["kr"].to_numpy()
SurfacePoolID=SurfaceData_Pool["Surface_ID"].to_numpy()

Iteration_num=50 # number of NN members
SurfaceTrain=[]
SurfaceReal=[]
# Out:
# <ipython-input-12-ec27b520723c>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurfaceData_Simulated=SurfaceData_Simulated[SurfaceData["DU"]>=6]## 6.7= ks+60   7.08=ks+70

# %%
for i in ListOfLabledID.astype(int):
    SurfaceTrain_row=[SurfaceData.iloc[i].kt/SurfaceData.iloc[i].K_99,SurfaceData.iloc[i].lambda0,SurfaceData.iloc[i].lambda1]
    SurfaceTrain_row.extend(SurfaceData.iloc[i].n0)
    SurfaceTrain_row.extend(SurfaceData.iloc[i].PSquerys)
    SurfaceTrain.append(SurfaceTrain_row)

# %%
from skopt import dump, load
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras import initializers, regularizers
from tensorflow.keras import losses
from tensorflow.keras import activations,Sequential
from tensorflow.keras import metrics
from sklearn.model_selection import KFold
import time
from tensorflow import keras
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler

space = [
    Integer(1, 256, name='n_neurons_0'),
    Integer(1, 256, name='n_neurons_1'),
    Integer(1, 256, name='n_neurons_2'),
    Categorical(['sigmoid','linear',"tanh", 'relu','leakyrelu'], name='activation'),
    Real(1e-4, 1e-1, prior='log-uniform', name='lr'),
    Real(1e-4, 1e-1, prior='log-uniform', name='regularization')
]
@use_named_args(dimensions=space)

def build_model(**space):
    model = keras.Sequential()
    # Add input layer; images have one channel (102, 302, 1)
    input_shape = 63
    if space['activation']=='leakyrelu':
        model.add(Dense(int(space['n_neurons_0']),input_shape=(input_shape,),activation=LeakyReLU(alpha=0.3),kernel_regularizer=regularizers.l2(space['regularization'])))
    else:
        model.add(Dense(int(space['n_neurons_0']),input_shape=(input_shape,),activation=layers.Activation(space['activation']),kernel_regularizer=regularizers.l2(space['regularization'])))
    for i in range(2):
        model.add(Dense(int(space['n_neurons_'+str(i+1)]),kernel_regularizer=regularizers.l2(space['regularization'])))
        if space['activation'] == 'leakyrelu':
            model.add(LeakyReLU(alpha=0.3))
        else:
            model.add(layers.Activation(space['activation']))
    # Add output layer
    model.add(Dense(1,kernel_regularizer=regularizers.l2(space['regularization'])))
    if space['activation'] == 'leakyrelu':
        model.add(LeakyReLU(alpha=0.3))
    else:
        model.add(layers.Activation(space['activation']))
    # Compile the model
    model.compile(optimizer=keras.optimizers.Adam(space['lr']), loss=losses.MeanSquaredError(),
                  metrics=[keras.metrics.MeanSquaredError(),keras.metrics.MeanAbsolutePercentageError(name="MAPE")])
    return model
def lr_scheduler(epoch, learning_rate):
    lr = learning_rate
    if epoch == 1000:
        learning_rate = lr*0.5
        return learning_rate
    elif epoch == 1500:
        learning_rate = lr*0.5
        return learning_rate
    elif epoch == 1800:
        learning_rate = lr*0.5
        return learning_rate
    else:
        learning_rate = lr
        return learning_rate
    
new_lr = LearningRateScheduler(lr_scheduler, verbose=0)
def output_val_loss_BO(epoch,logs):
    print('the keys are:{}'.format(logs.keys))
def objective(space):
    kfold=KFold(n_splits=10,shuffle=True)
    fold_num=1
    val_mse_k_fold=np.zeros(10);
    print('Current space')
    print(space)
    for train_id,val_id in kfold.split(SurfaceTrain,DUTrain):

        model = build_model(space)
        #start_epoch = time.time()
    # ckpt_filepath = './tmp_cnn_v1/cnn_ckpt/model_{epoch:03d}_{val_loss:.4f}.h5'
    # ckpt = ModelCheckpoint(ckpt_filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=300)
        X_train=SurfaceTrain[train_id]
        y_train=DUTrain[train_id]
        X_val=SurfaceTrain[val_id]
        y_val=DUTrain[val_id]
        history = model.fit(X_train, y_train, epochs=2000,
                        validation_data=(X_val, y_val),
                        callbacks=[new_lr,es],verbose=0)
        #print('---- training time for each evaluation %s seconds ----' % (time.time() - start_epoch))
        
        train_loss, val_mse = history.history['loss'], history.history['val_MAPE']
        val_mse_k_fold[fold_num-1]=np.min(val_mse)
        fold_num+=1
    val_mse_mean=np.mean(val_mse_k_fold)
    return np.min(val_mse_mean)

# %%
#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3)   
print("-----------Run BO to find the optimal hps------------")
result = gp_minimize(func=objective, dimensions=space, n_calls=60, acq_func='gp_hedge', n_restarts_optimizer=5,verbose=1)
print("Best parameters: ", result.x)
print("Minimum val loss: ", result.fun)
    
### edited by Jiasheng
ToSave={"n_neurons_0":result.x[0],"n_neurons_1":result.x[1],"n_neurons_2":result.x[2],'activation':result.x[3],"lr":result.x[4],"regularization":result.x[5]}
df=pd.DataFrame(ToSave,index=[0])
df.to_csv('./Hyperparameters_kfold.csv',index=False,sep=';')
####
# Out:
# -----------Run BO to find the optimal hps------------
# Iteration No: 1 started. Evaluating function at random point.
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Epoch 319: early stopping
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Epoch 1271: early stopping
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Epoch 1072: early stopping
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Epoch 1279: early stopping
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Epoch 571: early stopping
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Epoch 312: early stopping
# Current space
# [173, 16, 54, 'linear', 0.00017252243148301857, 0.0019464523767869038]
# Epoch 1691: early stopping
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 203.9959
# Function value obtained: 0.3525
# Current minimum: 0.3525
# Iteration No: 2 started. Evaluating function at random point.
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Epoch 467: early stopping
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Epoch 1308: early stopping
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Epoch 1283: early stopping
# Current space
# [193, 243, 167, 'relu', 0.008470816949573568, 0.012108444847917099]
# Epoch 1057: early stopping
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 305.8737
# Function value obtained: 5.7246
# Current minimum: 0.3525
# Iteration No: 3 started. Evaluating function at random point.
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Current space
# [230, 135, 178, 'tanh', 0.002405008905902335, 0.0005455376443281601]
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 369.9170
# Function value obtained: 1.8507
# Current minimum: 0.3525
# Iteration No: 4 started. Evaluating function at random point.
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 1268: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 523: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 1203: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 360: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 1214: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 1199: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 1215: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 1276: early stopping
# Current space
# [87, 239, 172, 'relu', 0.0010349610012100098, 0.00370613291330212]
# Epoch 1775: early stopping
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 233.6140
# Function value obtained: 0.1681
# Current minimum: 0.1681
# Iteration No: 5 started. Evaluating function at random point.
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Current space
# [100, 91, 79, 'tanh', 0.002002449178285084, 0.09402020612310319]
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 346.8119
# Function value obtained: 1.6778
# Current minimum: 0.1681
# Iteration No: 6 started. Evaluating function at random point.
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Epoch 301: early stopping
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Epoch 1587: early stopping
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Epoch 496: early stopping
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Epoch 1642: early stopping
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Epoch 1596: early stopping
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Epoch 780: early stopping
# Current space
# [48, 74, 35, 'relu', 0.0436643133527255, 0.001310102200811757]
# Epoch 984: early stopping
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 239.9756
# Function value obtained: 4.5506
# Current minimum: 0.1681
# Iteration No: 7 started. Evaluating function at random point.
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Current space
# [37, 84, 51, 'tanh', 0.009733685926400835, 0.018767629067408743]
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 351.1179
# Function value obtained: 1.5289
# Current minimum: 0.1681
# Iteration No: 8 started. Evaluating function at random point.
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 818: early stopping
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 1009: early stopping
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 563: early stopping
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 869: early stopping
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 1706: early stopping
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 841: early stopping
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 772: early stopping
# Current space
# [95, 99, 195, 'relu', 0.00615164790517129, 0.0007661852237321492]
# Epoch 377: early stopping
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 203.4184
# Function value obtained: 4.8472
# Current minimum: 0.1681
# Iteration No: 9 started. Evaluating function at random point.
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Current space
# [211, 6, 16, 'sigmoid', 0.015375714611049118, 0.023861350143792794]
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 354.9063
# Function value obtained: 1.6671
# Current minimum: 0.1681
# Iteration No: 10 started. Evaluating function at random point.
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Current space
# [131, 145, 59, 'linear', 0.00018636546214151572, 0.07948822973146652]
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 380.5595
# Function value obtained: 0.2451
# Current minimum: 0.1681
# Iteration No: 11 started. Searching for the next optimal point.
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1787: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1164: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1188: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1151: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1721: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1360: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1591: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 1134: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Epoch 902: early stopping
# Current space
# [1, 256, 115, 'linear', 0.0005043465195177701, 0.1]
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 265.5664
# Function value obtained: 0.3552
# Current minimum: 0.1681
# Iteration No: 12 started. Searching for the next optimal point.
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Epoch 1785: early stopping
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Current space
# [37, 256, 72, 'linear', 0.00022695439934566843, 0.1]
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 377.6295
# Function value obtained: 0.2206
# Current minimum: 0.1681
# Iteration No: 13 started. Searching for the next optimal point.
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1184: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1674: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1441: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1521: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1945: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1260: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1222: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 911: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1573: early stopping
# Current space
# [30, 246, 93, 'relu', 0.0003641110101092604, 0.1]
# Epoch 1753: early stopping
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 287.1213
# Function value obtained: 0.2478
# Current minimum: 0.1681
# Iteration No: 14 started. Searching for the next optimal point.
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Current space
# [256, 256, 256, 'tanh', 0.00033732445921567375, 0.1]
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 435.2343
# Function value obtained: 2.2740
# Current minimum: 0.1681
# Iteration No: 15 started. Searching for the next optimal point.
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1222: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1224: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1487: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1269: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 635: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1280: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1165: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1102: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1549: early stopping
# Current space
# [68, 129, 169, 'relu', 0.0009215042106077682, 0.004663218040800263]
# Epoch 1798: early stopping
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 256.0458
# Function value obtained: 0.2287
# Current minimum: 0.1681
# Iteration No: 16 started. Searching for the next optimal point.
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Epoch 1773: early stopping
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Epoch 1840: early stopping
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Epoch 1560: early stopping
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Epoch 1783: early stopping
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Epoch 1417: early stopping
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Epoch 1998: early stopping
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Epoch 1776: early stopping
# Current space
# [256, 256, 256, 'linear', 0.00027522155952587824, 0.1]
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 388.9526
# Function value obtained: 0.2373
# Current minimum: 0.1681
# Iteration No: 17 started. Searching for the next optimal point.
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1230: early stopping
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1122: early stopping
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1158: early stopping
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1787: early stopping
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1226: early stopping
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1252: early stopping
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1298: early stopping
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Current space
# [234, 256, 63, 'relu', 0.0009821931909585423, 0.003525157649119618]
# Epoch 1282: early stopping
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 310.0890
# Function value obtained: 0.1775
# Current minimum: 0.1681
# Iteration No: 18 started. Searching for the next optimal point.
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 1239: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 1269: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 1167: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 1020: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 968: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 414: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 1144: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Epoch 1254: early stopping
# Current space
# [214, 256, 32, 'relu', 0.00110059173229308, 0.002565824863440761]
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 267.7812
# Function value obtained: 0.1519
# Current minimum: 0.1519
# Iteration No: 19 started. Searching for the next optimal point.
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Epoch 1251: early stopping
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Epoch 1756: early stopping
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Epoch 1649: early stopping
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Epoch 1240: early stopping
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Epoch 1253: early stopping
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Epoch 1623: early stopping
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Epoch 1753: early stopping
# Current space
# [256, 256, 64, 'relu', 0.00023798189019971403, 0.1]
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 355.2456
# Function value obtained: 0.3111
# Current minimum: 0.1519
# Iteration No: 20 started. Searching for the next optimal point.
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 1231: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 320: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 1296: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 484: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 402: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 436: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 723: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 674: early stopping
# Current space
# [256, 256, 1, 'relu', 0.0011210135419459984, 0.0001]
# Epoch 916: early stopping
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 182.8591
# Function value obtained: 4.3425
# Current minimum: 0.1519
# Iteration No: 21 started. Searching for the next optimal point.
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 906: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 583: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 1279: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 1467: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 1220: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 1305: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 1288: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 518: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 540: early stopping
# Current space
# [1, 1, 136, 'relu', 0.0010946770501488905, 0.002895209560396673]
# Epoch 870: early stopping
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 199.9973
# Function value obtained: 3.4990
# Current minimum: 0.1519
# Iteration No: 22 started. Searching for the next optimal point.
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Current space
# [109, 255, 104, 'linear', 0.0001, 0.0998862265809344]
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 416.6495
# Function value obtained: 0.2480
# Current minimum: 0.1519
# Iteration No: 23 started. Searching for the next optimal point.
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Epoch 1565: early stopping
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Epoch 1781: early stopping
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Epoch 1717: early stopping
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Epoch 1735: early stopping
# Current space
# [97, 67, 148, 'relu', 0.00014009622251600053, 0.1]
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 385.3399
# Function value obtained: 5.8338
# Current minimum: 0.1519
# Iteration No: 24 started. Searching for the next optimal point.
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 1231: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 521: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 1168: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 1759: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 974: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 973: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 1228: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 1241: early stopping
# Current space
# [188, 251, 94, 'relu', 0.0009357326531459402, 0.0030855376061985074]
# Epoch 1297: early stopping
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 265.7230
# Function value obtained: 0.1936
# Current minimum: 0.1519
# Iteration No: 25 started. Searching for the next optimal point.
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Epoch 1703: early stopping
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Epoch 1296: early stopping
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Epoch 1294: early stopping
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Epoch 1265: early stopping
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Current space
# [52, 159, 115, 'relu', 0.0006380071760771223, 0.004302548250605372]
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 361.2268
# Function value obtained: 0.1735
# Current minimum: 0.1519
# Iteration No: 26 started. Searching for the next optimal point.
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Current space
# [256, 199, 224, 'linear', 0.0001, 0.08888382380833854]
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 430.6669
# Function value obtained: 0.2567
# Current minimum: 0.1519
# Iteration No: 27 started. Searching for the next optimal point.
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Current space
# [189, 212, 111, 'relu', 0.1, 0.0037468644379176127]
# Epoch 301: early stopping
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 71.5424
# Function value obtained: 4.6786
# Current minimum: 0.1519
# Iteration No: 28 started. Searching for the next optimal point.
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 1179: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 881: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 915: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 1750: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 1207: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 852: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 1213: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 543: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 1282: early stopping
# Current space
# [1, 256, 119, 'relu', 0.0005556308575424403, 0.1]
# Epoch 708: early stopping
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 218.0526
# Function value obtained: 0.2479
# Current minimum: 0.1519
# Iteration No: 29 started. Searching for the next optimal point.
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1787: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 579: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1752: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1191: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1562: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1746: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1158: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1159: early stopping
# Current space
# [62, 230, 179, 'relu', 0.0007298094919441903, 0.003876817488705613]
# Epoch 1176: early stopping
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 306.6620
# Function value obtained: 0.1739
# Current minimum: 0.1519
# Iteration No: 30 started. Searching for the next optimal point.
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Epoch 1992: early stopping
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Epoch 1777: early stopping
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Current space
# [256, 230, 256, 'linear', 0.00019798285278869378, 0.07689648464025381]
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 439.2386
# Function value obtained: 0.1932
# Current minimum: 0.1519
# Iteration No: 31 started. Searching for the next optimal point.
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Epoch 1273: early stopping
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Epoch 1189: early stopping
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Epoch 1724: early stopping
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Epoch 1256: early stopping
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Epoch 955: early stopping
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Epoch 613: early stopping
# Current space
# [178, 151, 179, 'relu', 0.000659973695606111, 0.004763726759045368]
# Epoch 541: early stopping
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 297.7503
# Function value obtained: 0.1560
# Current minimum: 0.1519
# Iteration No: 32 started. Searching for the next optimal point.
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1644: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1300: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1739: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1491: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1884: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1229: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1279: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1273: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1620: early stopping
# Current space
# [115, 167, 246, 'relu', 0.0007955054070223222, 0.004483239842864511]
# Epoch 1778: early stopping
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 329.5675
# Function value obtained: 0.1307
# Current minimum: 0.1307
# Iteration No: 33 started. Searching for the next optimal point.
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Epoch 1547: early stopping
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Epoch 972: early stopping
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Epoch 1183: early stopping
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Epoch 1780: early stopping
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Epoch 1607: early stopping
# Current space
# [1, 256, 1, 'relu', 0.00038230881910701533, 0.08099422885014895]
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 342.0662
# Function value obtained: 4.6528
# Current minimum: 0.1307
# Iteration No: 34 started. Searching for the next optimal point.
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1775: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1772: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1167: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1184: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1579: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1137: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1706: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1250: early stopping
# Current space
# [100, 256, 174, 'relu', 0.00068739262368508, 0.002642407699875374]
# Epoch 1716: early stopping
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 339.4866
# Function value obtained: 0.1228
# Current minimum: 0.1228
# Iteration No: 35 started. Searching for the next optimal point.
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 355: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 423: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 1958: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 1141: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 1275: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 660: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 694: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 1152: early stopping
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Current space
# [1, 237, 197, 'relu', 0.0006580229450535916, 0.0035478526624849473]
# Epoch 1129: early stopping
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 230.8904
# Function value obtained: 2.9702
# Current minimum: 0.1228
# Iteration No: 36 started. Searching for the next optimal point.
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Epoch 1746: early stopping
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Epoch 1990: early stopping
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Current space
# [170, 194, 255, 'leakyrelu', 0.0002389153630939228, 0.00845020131691195]
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 444.4961
# Function value obtained: 0.1853
# Current minimum: 0.1228
# Iteration No: 37 started. Searching for the next optimal point.
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 1178: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 1266: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 1279: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 1585: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 463: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 1705: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 1282: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 684: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 904: early stopping
# Current space
# [193, 50, 246, 'relu', 0.0007795832701977998, 0.0059013407921315025]
# Epoch 1770: early stopping
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 257.7259
# Function value obtained: 0.1338
# Current minimum: 0.1228
# Iteration No: 38 started. Searching for the next optimal point.
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1254: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1248: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1249: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1272: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1247: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1222: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1173: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1733: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1768: early stopping
# Current space
# [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Epoch 1278: early stopping
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 300.8307
# Function value obtained: 0.1074
# Current minimum: 0.1074
# Iteration No: 39 started. Searching for the next optimal point.
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 826: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 1145: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 954: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 1070: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 1217: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 746: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 1027: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 1279: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 1095: early stopping
# Current space
# [10, 255, 48, 'leakyrelu', 0.0010102464873001035, 0.1]
# Epoch 1175: early stopping
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 225.5594
# Function value obtained: 0.3040
# Current minimum: 0.1074
# Iteration No: 40 started. Searching for the next optimal point.
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Current space
# [169, 204, 43, 'tanh', 0.0010339061456629659, 0.0003466232516589748]
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 433.8518
# Function value obtained: 1.8513
# Current minimum: 0.1074
# Iteration No: 41 started. Searching for the next optimal point.
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 325: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 1008: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 535: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 393: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 817: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 534: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 366: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 547: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 1298: early stopping
# Current space
# [141, 187, 246, 'relu', 0.0007987107612967203, 0.0001]
# Epoch 321: early stopping
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 141.9792
# Function value obtained: 0.1800
# Current minimum: 0.1074
# Iteration No: 42 started. Searching for the next optimal point.
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 1216: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 1188: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 907: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 867: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 542: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 474: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 570: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 786: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 692: early stopping
# Current space
# [1, 256, 245, 'leakyrelu', 0.0021079536033134674, 0.1]
# Epoch 919: early stopping
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 181.3291
# Function value obtained: 0.3453
# Current minimum: 0.1074
# Iteration No: 43 started. Searching for the next optimal point.
# Current space
# [166, 201, 246, 'relu', 0.0007953165118178811, 0.1]
# Epoch 1070: early stopping
# Current space
# [166, 201, 246, 'relu', 0.0007953165118178811, 0.1]
# Epoch 735: early stopping
# Current space
# [166, 201, 246, 'relu', 0.0007953165118178811, 0.1]
# Epoch 859: early stopping
# Current space
# ...
# Current space
# [248, 231, 32, 'linear', 0.0010959428480163923, 0.0026866957616047313]
# Current space
# [248, 231, 32, 'linear', 0.0010959428480163923, 0.0026866957616047313]
# Current space
# [248, 231, 32, 'linear', 0.0010959428480163923, 0.0026866957616047313]
# Current space
# [248, 231, 32, 'linear', 0.0010959428480163923, 0.0026866957616047313]
# Current space
# [248, 231, 32, 'linear', 0.0010959428480163923, 0.0026866957616047313]
# Current space
# [248, 231, 32, 'linear', 0.0010959428480163923, 0.0026866957616047313]
# Current space
# [248, 231, 32, 'linear', 0.0010959428480163923, 0.0026866957616047313]
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 431.0100
# Function value obtained: 0.1518
# Current minimum: 0.1074
# Iteration No: 48 started. Searching for the next optimal point.
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1276: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1293: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1220: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1789: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1722: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1188: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1198: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1228: early stopping
# Current space
# [129, 132, 174, 'relu', 0.0007811331240598667, 0.003856667930089957]
# Epoch 1769: early stopping
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 319.1355
# Function value obtained: 0.1164
# Current minimum: 0.1074
# Iteration No: 49 started. Searching for the next optimal point.
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Current space
# [25, 256, 115, 'sigmoid', 0.0005069673328149111, 0.1]
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 429.4749
# Function value obtained: 1.5599
# Current minimum: 0.1074
# Iteration No: 50 started. Searching for the next optimal point.
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Current space
# [189, 162, 34, 'linear', 0.0010863060384695995, 0.0040198444173901735]
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 431.0625
# Function value obtained: 0.2681
# Current minimum: 0.1074
# Iteration No: 51 started. Searching for the next optimal point.
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Epoch 1695: early stopping
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Epoch 1864: early stopping
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Epoch 603: early stopping
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Epoch 1760: early stopping
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Epoch 304: early stopping
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Current space
# [219, 256, 93, 'linear', 0.0006897860734043045, 0.0009411604550507985]
# Epoch 315: early stopping
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 326.8009
# Function value obtained: 0.1539
# Current minimum: 0.1074
# Iteration No: 52 started. Searching for the next optimal point.
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 1662: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 348: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 867: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 1627: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 514: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 1225: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 579: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 379: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 613: early stopping
# Current space
# [76, 48, 235, 'linear', 0.0001, 0.0001]
# Epoch 398: early stopping
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 176.0804
# Function value obtained: 0.2488
# Current minimum: 0.1074
# Iteration No: 53 started. Searching for the next optimal point.
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Current space
# [2, 195, 95, 'linear', 0.00010266814586009488, 0.020522349722118482]
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 419.3399
# Function value obtained: 0.3433
# Current minimum: 0.1074
# Iteration No: 54 started. Searching for the next optimal point.
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 1754: early stopping
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 601: early stopping
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 1278: early stopping
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 1253: early stopping
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 1288: early stopping
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 1265: early stopping
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 1269: early stopping
# Current space
# [74, 211, 175, 'relu', 0.0007655335790296584, 0.0031466890701672776]
# Epoch 1285: early stopping
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 310.0451
# Function value obtained: 0.1991
# Current minimum: 0.1074
# Iteration No: 55 started. Searching for the next optimal point.
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 426: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 1141: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 465: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 362: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 350: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 418: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 381: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 406: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 311: early stopping
# Current space
# [18, 161, 253, 'leakyrelu', 0.0001483161266647669, 0.0001]
# Epoch 1419: early stopping
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 127.2557
# Function value obtained: 0.2893
# Current minimum: 0.1074
# Iteration No: 56 started. Searching for the next optimal point.
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 1795: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 1132: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 960: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 1798: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 636: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 1250: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 1263: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Epoch 1177: early stopping
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Current space
# [28, 99, 115, 'relu', 0.0006800433895814668, 0.001765056677350867]
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 298.0687
# Function value obtained: 2.7960
# Current minimum: 0.1074
# Iteration No: 57 started. Searching for the next optimal point.
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Epoch 1802: early stopping
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Epoch 1937: early stopping
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Epoch 1775: early stopping
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Current space
# [183, 202, 248, 'linear', 0.0007350877977187341, 0.034674924342447316]
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 440.3467
# Function value obtained: 0.2242
# Current minimum: 0.1074
# Iteration No: 58 started. Searching for the next optimal point.
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1992: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1725: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1260: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1245: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1781: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1274: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1294: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1301: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1187: early stopping
# Current space
# [228, 256, 102, 'leakyrelu', 0.0004594256670833203, 0.058808991579775025]
# Epoch 1075: early stopping
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 321.6020
# Function value obtained: 0.1815
# Current minimum: 0.1074
# Iteration No: 59 started. Searching for the next optimal point.
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1270: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1199: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1079: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1171: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1265: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1299: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 706: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1184: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1291: early stopping
# Current space
# [38, 250, 121, 'relu', 0.0005901129615487632, 0.07670074342540455]
# Epoch 1274: early stopping
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 256.5885
# Function value obtained: 0.2229
# Current minimum: 0.1074
# Iteration No: 60 started. Searching for the next optimal point.
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Epoch 1769: early stopping
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Epoch 1696: early stopping
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Current space
# [219, 256, 39, 'linear', 0.0011434249753846625, 0.04882823090568506]
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 427.0597
# Function value obtained: 0.2595
# Current minimum: 0.1074
# Best parameters:  [98, 256, 246, 'relu', 0.0008007144914500873, 0.002744270725961709]
# Minimum val loss:  0.10741592198610306

# %%
ToSave={"n_neurons_0":result.x[0],"n_neurons_1":result.x[1],"n_neurons_2":result.x[2],'activation':result.x[3],"lr":result.x[4],"regularization":result.x[5]}
df=pd.DataFrame(ToSave,index=[0])
df.to_csv('./Hyperparameters_BO.csv',index=False,sep=';')

# %%
val_loss_history=result.func_vals
plt.plot(val_loss_history,color=[0,130/255,150/255],linewidth=3)
plt.plot(np.argmin(val_loss_history),np.min(val_loss_history),'ro')
plt.legend(["BO","selected","Previous"])
plt.xlabel("BO iterations")
plt.ylabel("val_loss")
plt.show()
